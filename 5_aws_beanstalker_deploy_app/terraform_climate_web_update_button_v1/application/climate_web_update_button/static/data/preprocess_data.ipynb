# %% [markdown]
# ### objective:
# - preprocess the data to fit and visualize on the map
# - resize the ROW numbers

# %%
import numpy as np
import pandas as pd

# %%
df_a= pd.read_csv("../data/xco2_anomalies_2014.csv")
df_a.head(3)
# Out:
#    ngfed_id        x       y  year  month   mean_xco2  mean_xco2_anomaly  \
# 0    236794 -179.875 -15.875  2014      9  397.378316           1.130398
# 1    236429 -179.875 -15.625  2014      9  397.171053           0.923134
# 2    239871 -179.375 -17.875  2014      9  394.890094          -1.174814
#
#    Index
# 0      0
# 1      1
# 2      2

# %%
len(df_a)
# Out:
# 90630

# %%
len(df_a[::2])
# Out:
# 45315

# %%
df_a["mean_xco2_anomaly"].plot()
df_a[::2]["mean_xco2_anomaly"].plot(linewidth=.5, alpha= 0.3, color="red")
# Out:
# <AxesSubplot:>

# %%
## decrease the row
df_new= df_a[::10]
df_new.to_csv("xco2_anomalies_2014_shorten.csv", index=False)
